# %% [markdown]
# <a href="https://colab.research.google.com/github/Prathamgupta19/Machine-learning-projects-/blob/main/ece_placemnets_stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('/content/Copy of ECE Placemnets 2026 (1) (1).xlsx')

# %%
data.head()
# Out:
#   Dept Rank               Name     Roll no   Sno  CGPA upto 6th sem   \
# 0        209  AAKANKSHA KAUSHAL  2K22/EC/01  1.0               5.442
# 1         14    AAKARSH GUNJESH  2K22/EC/02  2.0               9.106
# 2        238       AAKASH NIGAM  2K22/EC/03  3.0               4.316
# 3          6     AAKSHAT JINDAL  2K22/EC/04  4.0               9.271
# 4         82      AARYAN MITTAL  2K22/EC/06  6.0               7.880
#
#   Placement Status                                  Company    CTC Unnamed: 8
# 0               NaN                                      NaN   NaN        NaN
# 1               NaN                                      NaN   NaN        NaN
# 2               NaN                                      NaN   NaN        NaN
# 3              YES   Trusave Fintech (bachatt) 6M + FTE 2026  23.5        NaN
# 4               NaN                                      NaN   NaN        NaN

# %%
df = data[data['Placement Status '].isin(['YES', ' YES' , 'YES ' , ' YES '])]

# %%
df.head()
# Out:
#    Dept Rank              Name     Roll no    Sno  CGPA upto 6th sem   \
# 3           6    AAKSHAT JINDAL  2K22/EC/04   4.0               9.271
# 5         123     AASHIR REHMAN  2K22/EC/07   7.0               7.315
# 11          1  ABHRONEEL MOITRA  2K22/EC/13  13.0               9.680
# 13        177            ADITYA  2K22/EC/15  15.0               6.237
# 20         21      ADVAITA SONI  2K22/EC/22  22.0               8.957
#
#    Placement Status                                      Company     CTC  \
# 3               YES       Trusave Fintech (bachatt) 6M + FTE 2026  23.50
# 5                YES  ZS Associates 6M+FTE 2026 | BCN 6M+PPO 2026  14.15
# 11               YES                      Qualcomm 6M + FTE 2026   31.05
# 13               YES                  Futures First 6M + PPO 2026  17.00
# 20              YES                                      Expedia    0.40
#
#    Unnamed: 8
# 3         NaN
# 5       15.68
# 11        NaN
# 13        NaN
# 20        ppo

# %%
df.tail()
# Out:
#     Dept Rank           Name      Roll no     Sno  CGPA upto 6th sem   \
# 235          7     UDIT SINGH  2K22/EC/243  243.0               9.242
# 244         39  YANSHI SHARMA  2K22/EC/252  252.0               8.678
# 245         28     YASH ARORA  2K22/EC/253  253.0               8.862
# 246         35     YASH KUMAR  2K22/EC/254  254.0               8.728
# 247         12    YASH SHARMA  2K22/EC/255  255.0               9.124
#
#     Placement Status                  Company     CTC Unnamed: 8
# 235               YES  Qualcomm 6M + FTE 2026   31.05        NaN
# 244              YES             Natwest Group  15.00        NaN
# 245              YES      OYO BA 6M + PPO 2026  11.50        NaN
# 246              YES             Ciena 6M+PPO   14.00        NaN
# 247              YES   Qualcomm 6M + FTE 2026   31.05        NaN

# %%
df_ = df.CTC

# %%
df_.head()
# Out:
# 3     23.50
# 5     14.15
# 11    31.05
# 13    17.00
# 20     0.40
# Name: CTC, dtype: float64

# %%
df_.describe()
# Out:
# count    51.000000
# mean     22.105686
# std      10.694145
# min       0.400000
# 25%      14.150000
# 50%      19.500000
# 75%      28.000000
# max      57.000000
# Name: CTC, dtype: float64
